# %% [markdown]
# ## 	Another Program should then read the created model file, and use it to predict evaluation data.

# %%
import pandas as pd

# %%
data = pd.read_csv('aml_eval_with_predictions.csv') #loading the preprocessed dataset

# %%
data.head(pd.reset_option('display.max_rows',None)) # Used to display the all features
# Out:
#      Unnamed: 0     token  TransactionType    amount  CurrentBalanceSender  \
# 0             0  0.017663             0.00  0.000292              0.000000
# 1             1  0.733696             0.50  0.010726              0.000000
# 2             2  0.445652             1.00  0.008425              0.000000
# 3             3  0.502717             0.25  0.015370              0.049887
# 4             4  0.486413             0.00  0.000512              0.000411
# ..          ...       ...              ...       ...                   ...
# 995         995  0.417120             0.00  0.000875              0.000087
# 996         996  0.737772             0.25  0.002415              0.128731
# 997         997  0.896739             0.00  0.000497              0.000000
# 998         998  0.308424             0.50  1.000000              0.000000
# 999         999  0.044837             0.00  0.001166              0.000000
#
# ...

# %% [markdown]
# - **Model prediction is Successfull**
